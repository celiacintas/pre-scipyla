# %% [markdown]
# ## Paseando por pandas

# %%
from IPython.display import IFrame
IFrame('http://pandas.pydata.org/', width=900, height=350)
# Out:
#         <iframe
#             width="900"
#             height="350"
#             src="http://pandas.pydata.org/"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# #### Importamos las bibliotecas a usar ...

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# <table width="500px" height="100%"  border="1" style="border: 2px solid red; background-color: ##CC3333 ;">
# <td color="solid green" border= "solid green">
# <img src="images/light.jpg" align='left' alt="description here" />
#  <br>
#  **También mirar:
#  read_excel, read_clipboard, read_fwf, read_html, read_json, read_sql**
#  </td>
# </table>

# %%
df = pd.read_csv('data/training.csv', na_values=-999)
# Reemplazamos nuestros valores de 'y' con valores enteros.
df['Label'] = df['Label'].map({'s': 0, 'b':1}).astype(int)

# %%
df.head(10)
# Out:
#    EventId  DER_mass_MMC  DER_mass_transverse_met_lep  DER_mass_vis  DER_pt_h  \
# 0   100000       138.470                       51.655        97.827    27.980
# 1   100001       160.937                       68.768       103.235    48.146
# 2   100002           NaN                      162.172       125.953    35.635
# 3   100003       143.905                       81.417        80.943     0.414
# 4   100004       175.864                       16.915       134.805    16.405
# 5   100005        89.744                       13.550        59.149   116.344
# 6   100006       148.754                       28.862       107.782   106.130
# 7   100007       154.916                       10.418        94.714    29.169
# 8   100008       105.594                       50.559       100.989     4.288
# 9   100009       128.053                       88.941        69.272   193.392
#
#    DER_deltaeta_jet_jet  DER_mass_jet_jet  DER_prodeta_jet_jet  \
# 0                 0.910           124.711                2.666
# 1                   NaN               NaN                  NaN
# 2                   NaN               NaN                  NaN
# 3                   NaN               NaN                  NaN
# 4                   NaN               NaN                  NaN
# 5                 2.636           284.584               -0.540
# 6                 0.733           158.359                0.113
# 7                   NaN               NaN                  NaN
# 8                   NaN               NaN                  NaN
# 9                   NaN               NaN                  NaN
#
#    DER_deltar_tau_lep  DER_pt_tot     ...      PRI_jet_num  \
# 0               3.064      41.928     ...                2
# 1               3.473       2.078     ...                1
# 2               3.148       9.336     ...                1
# 3               3.310       0.414     ...                0
# 4               3.891      16.405     ...                0
# 5               1.362      61.619     ...                3
# 6               2.941       2.545     ...                2
# 7               2.897       1.526     ...                1
# 8               2.904       4.288     ...                0
# 9               1.609      28.859     ...                1
#
#    PRI_jet_leading_pt  PRI_jet_leading_eta  PRI_jet_leading_phi  \
# 0              67.435                2.150                0.444
# 1              46.226                0.725                1.158
# 2              44.251                2.053               -2.028
# 3                 NaN                  NaN                  NaN
# 4                 NaN                  NaN                  NaN
# 5              90.547               -2.412               -0.653
# 6             123.010                0.864                1.450
# 7              30.638               -0.715               -1.724
# 8                 NaN                  NaN                  NaN
# 9             167.735               -2.767               -2.514
#
#    PRI_jet_subleading_pt  PRI_jet_subleading_eta  PRI_jet_subleading_phi  \
# 0                 46.062                   1.240                  -2.475
# 1                    NaN                     NaN                     NaN
# 2                    NaN                     NaN                     NaN
# 3                    NaN                     NaN                     NaN
# 4                    NaN                     NaN                     NaN
# 5                 56.165                   0.224                   3.106
# 6                 56.867                   0.131                  -2.767
# 7                    NaN                     NaN                     NaN
# 8                    NaN                     NaN                     NaN
# 9                    NaN                     NaN                     NaN
#
#    PRI_jet_all_pt    Weight  Label
# 0         113.497  0.002653      0
# 1          46.226  2.233584      1
# 2          44.251  2.347389      1
# 3          -0.000  5.446378      1
# 4           0.000  6.245333      1
# 5         193.660  0.083414      1
# 6         179.877  0.002653      0
# 7          30.638  0.018636      0
# 8           0.000  5.296003      1
# 9         167.735  0.001502      0
#
# [10 rows x 33 columns]

# %%
df.describe()
# Out:
#              EventId   DER_mass_MMC  DER_mass_transverse_met_lep  \
# count  250000.000000  211886.000000                250000.000000
# mean   224999.500000     121.858528                    49.239819
# std     72168.927986      57.298157                    35.344886
# min    100000.000000       9.044000                     0.000000
# 25%    162499.750000      91.885250                    19.241000
# 50%    224999.500000     112.406000                    46.524000
# 75%    287499.250000     135.482000                    73.598000
# max    349999.000000    1192.026000                   690.075000
#
#         DER_mass_vis       DER_pt_h  DER_deltaeta_jet_jet  DER_mass_jet_jet  \
# count  250000.000000  250000.000000          72543.000000      72543.000000
# mean       81.181982      57.895962              2.403735        371.783360
# std        40.828691      63.655682              1.742226        397.699325
# min         6.329000       0.000000              0.000000         13.602000
# 25%        59.388750      14.068750              0.882500        111.977000
# 50%        73.752000      38.467500              2.107000        225.885000
# 75%        92.259000      79.169000              3.690000        478.226000
# max      1349.351000    2834.999000              8.503000       4974.979000
#
#        DER_prodeta_jet_jet  DER_deltar_tau_lep     DER_pt_tot      ...        \
# count         72543.000000       250000.000000  250000.000000      ...
# mean             -0.821688            2.373100      18.917332      ...
# std               3.584362            0.782911      22.273494      ...
# min             -18.066000            0.208000       0.000000      ...
# 25%              -2.629000            1.810000       2.841000      ...
# 50%              -0.244000            2.491500      12.315500      ...
# 75%               0.958000            2.961000      27.591000      ...
# max              16.690000            5.684000    2834.999000      ...
#
#          PRI_jet_num  PRI_jet_leading_pt  PRI_jet_leading_eta  \
# count  250000.000000       150087.000000        150087.000000
# mean        0.979176           84.822105            -0.003275
# std         0.977426           60.662276             1.784546
# min         0.000000           30.000000            -4.499000
# 25%         0.000000           44.422500            -1.342000
# 50%         1.000000           65.561000             0.000000
# 75%         2.000000          103.342000             1.336000
# max         3.000000         1120.573000             4.499000
#
#        PRI_jet_leading_phi  PRI_jet_subleading_pt  PRI_jet_subleading_eta  \
# count        150087.000000           72543.000000            72543.000000
# mean             -0.012393              57.679474               -0.011845
# std               1.813385              31.985782                2.031743
# min              -3.142000              30.000000               -4.500000
# 25%              -1.584000              37.312000               -1.612000
# 50%              -0.033000              47.902000               -0.010000
# 75%               1.562000              66.637000                1.589500
# max               3.141000             721.456000                4.500000
#
#        PRI_jet_subleading_phi  PRI_jet_all_pt         Weight          Label
# count            72543.000000   250000.000000  250000.000000  250000.000000
# mean                -0.001582       73.064591       1.646767       0.657332
# std                  1.816950       98.015662       1.875103       0.474603
# min                 -3.142000        0.000000       0.001502       0.000000
# 25%                 -1.576500        0.000000       0.018636       0.000000
# 50%                 -0.002000       40.512500       1.156188       1.000000
# 75%                  1.576000      109.933750       2.404128       1.000000
# max                  3.142000     1633.433000       7.822543       1.000000
#
# [8 rows x 33 columns]

# %%
df.corr()
# Out:
#                               EventId  DER_mass_MMC  \
# EventId                      1.000000     -0.000214
# DER_mass_MMC                -0.000214      1.000000
# DER_mass_transverse_met_lep -0.006059      0.221152
# DER_mass_vis                -0.001851      0.911795
# DER_pt_h                     0.002073      0.023743
# DER_deltaeta_jet_jet         0.003741     -0.027467
# DER_mass_jet_jet             0.002357     -0.021716
# DER_prodeta_jet_jet         -0.004765      0.018621
# DER_deltar_tau_lep          -0.001349      0.497405
# DER_pt_tot                  -0.000581      0.013584
# DER_sum_pt                   0.001427      0.124621
# DER_pt_ratio_lep_tau        -0.001209      0.070503
# DER_met_phi_centrality       0.003393      0.020316
# DER_lep_eta_centrality       0.003225     -0.033955
# PRI_tau_pt                   0.002829      0.265951
# PRI_tau_eta                  0.001573      0.002594
# PRI_tau_phi                 -0.000467     -0.003091
# PRI_lep_pt                   0.000061      0.341073
# PRI_lep_eta                  0.001567      0.003538
# PRI_lep_phi                 -0.001934     -0.003216
# PRI_met                      0.000345      0.100093
# PRI_met_phi                 -0.001141     -0.000081
# PRI_met_sumet                0.002312      0.088447
# PRI_jet_num                  0.000175      0.015205
# PRI_jet_leading_pt           0.002797      0.006454
# PRI_jet_leading_eta          0.002993      0.002453
# PRI_jet_leading_phi          0.002165      0.006588
# PRI_jet_subleading_pt       -0.000039     -0.016114
# PRI_jet_subleading_eta      -0.002718      0.004979
# PRI_jet_subleading_phi       0.003632     -0.001914
# PRI_jet_all_pt               0.001024      0.011093
# Weight                      -0.002838      0.098785
# Label                       -0.002248     -0.011615
#
#                              DER_mass_transverse_met_lep  DER_mass_vis  \
# EventId                                        -0.006059     -0.001851
# DER_mass_MMC                                    0.221152      0.911795
# DER_mass_transverse_met_lep                     1.000000      0.190109
# DER_mass_vis                                    0.190109      1.000000
# DER_pt_h                                       -0.249116     -0.062562
# DER_deltaeta_jet_jet                           -0.134007     -0.039032
# DER_mass_jet_jet                               -0.132298     -0.055280
# DER_prodeta_jet_jet                             0.123520      0.032945
# DER_deltar_tau_lep                              0.043251      0.579712
# DER_pt_tot                                      0.017758     -0.000702
# DER_sum_pt                                     -0.146837      0.088685
# DER_pt_ratio_lep_tau                            0.349504      0.097490
# DER_met_phi_centrality                         -0.419757     -0.090846
# DER_lep_eta_centrality                         -0.109206     -0.053415
# PRI_tau_pt                                     -0.145464      0.290011
# PRI_tau_eta                                    -0.002109      0.002127
# PRI_tau_phi                                     0.001132     -0.003624
# PRI_lep_pt                                      0.310648      0.405482
# PRI_lep_eta                                    -0.006777      0.002196
# PRI_lep_phi                                     0.000340     -0.002018
# PRI_met                                         0.183716     -0.087330
# PRI_met_phi                                    -0.015925     -0.001467
# PRI_met_sumet                                  -0.167811      0.053300
# PRI_jet_num                                    -0.210537     -0.026860
# PRI_jet_leading_pt                             -0.145892     -0.076472
# PRI_jet_leading_eta                             0.000072      0.002569
# PRI_jet_leading_phi                             0.006824      0.005583
# PRI_jet_subleading_pt                          -0.036199     -0.049472
# PRI_jet_subleading_eta                          0.001802      0.002181
# PRI_jet_subleading_phi                          0.006880     -0.000688
# PRI_jet_all_pt                                 -0.210009     -0.052902
# Weight                                          0.419843      0.102172
# Label                                           0.351428      0.014055
#
#                              DER_pt_h  DER_deltaeta_jet_jet  DER_mass_jet_jet  \
# EventId                      0.002073              0.003741          0.002357
# DER_mass_MMC                 0.023743             -0.027467         -0.021716
# DER_mass_transverse_met_lep -0.249116             -0.134007         -0.132298
# DER_mass_vis                -0.062562             -0.039032         -0.055280
# DER_pt_h                     1.000000             -0.037698          0.188946
# DER_deltaeta_jet_jet        -0.037698              1.000000          0.797181
# DER_mass_jet_jet             0.188946              0.797181          1.000000
# DER_prodeta_jet_jet         -0.026260             -0.835993         -0.763316
# DER_deltar_tau_lep          -0.539379              0.030562         -0.119081
# DER_pt_tot                   0.310501             -0.148028         -0.036482
# DER_sum_pt                   0.832733             -0.104416          0.230774
# DER_pt_ratio_lep_tau         0.089187             -0.084216         -0.050103
# DER_met_phi_centrality       0.539356              0.108203          0.151061
# DER_lep_eta_centrality       0.015513              0.644238          0.477761
# PRI_tau_pt                   0.407421              0.017844          0.114165
# PRI_tau_eta                  0.001665             -0.004450         -0.005978
# PRI_tau_phi                  0.005248             -0.003168          0.001116
# PRI_lep_pt                   0.360939             -0.079885          0.021857
# PRI_lep_eta                  0.008354             -0.006461         -0.003660
# PRI_lep_phi                 -0.002923              0.000217         -0.003774
# PRI_met                      0.679585             -0.059372          0.126627
# PRI_met_phi                  0.008585             -0.003103          0.001166
# PRI_met_sumet                0.782547             -0.141291          0.163529
# PRI_jet_num                  0.623401             -0.175495         -0.074390
# PRI_jet_leading_pt           0.826278             -0.043514          0.283724
# PRI_jet_leading_eta          0.002842             -0.002005         -0.000732
# PRI_jet_leading_phi          0.000993             -0.000819          0.000983
# PRI_jet_subleading_pt        0.360062             -0.090497          0.235312
# PRI_jet_subleading_eta       0.000192             -0.004843         -0.003059
# PRI_jet_subleading_phi      -0.007824              0.001234         -0.002185
# PRI_jet_all_pt               0.808616             -0.108775          0.240043
# Weight                      -0.414084             -0.277318         -0.276879
# Label                       -0.192526             -0.328305         -0.316727
#
#                              DER_prodeta_jet_jet  DER_deltar_tau_lep  \
# EventId                                -0.004765           -0.001349
# DER_mass_MMC                            0.018621            0.497405
# DER_mass_transverse_met_lep             0.123520            0.043251
# DER_mass_vis                            0.032945            0.579712
# DER_pt_h                               -0.026260           -0.539379
# DER_deltaeta_jet_jet                   -0.835993            0.030562
# DER_mass_jet_jet                       -0.763316           -0.119081
# DER_prodeta_jet_jet                     1.000000            0.010708
# DER_deltar_tau_lep                      0.010708            1.000000
# DER_pt_tot                              0.110272           -0.148081
# DER_sum_pt                              0.014377           -0.432603
# DER_pt_ratio_lep_tau                    0.061368            0.047046
# DER_met_phi_centrality                 -0.115384           -0.205441
# DER_lep_eta_centrality                 -0.560273           -0.017322
# PRI_tau_pt                             -0.040812           -0.202035
# PRI_tau_eta                             0.004152            0.003632
# PRI_tau_phi                             0.001442           -0.011229
# PRI_lep_pt                              0.038601           -0.069957
# PRI_lep_eta                             0.003629            0.000699
# PRI_lep_phi                             0.000236           -0.000776
# PRI_met                                 0.010155           -0.402345
# PRI_met_phi                             0.002677           -0.001570
# PRI_met_sumet                           0.047484           -0.407002
# PRI_jet_num                             0.123566           -0.347904
# PRI_jet_leading_pt                     -0.026637           -0.483625
# PRI_jet_leading_eta                    -0.003548           -0.000157
# PRI_jet_leading_phi                    -0.003038            0.006808
# PRI_jet_subleading_pt                   0.002877           -0.231997
# PRI_jet_subleading_eta                 -0.002528            0.001928
# PRI_jet_subleading_phi                  0.002133            0.007244
# PRI_jet_all_pt                          0.018037           -0.448737
# Weight                                  0.249448            0.197881
# Label                                   0.294340           -0.012245
#
#                              DER_pt_tot     ...      PRI_jet_num  \
# EventId                       -0.000581     ...         0.000175
# DER_mass_MMC                   0.013584     ...         0.015205
# DER_mass_transverse_met_lep    0.017758     ...        -0.210537
# DER_mass_vis                  -0.000702     ...        -0.026860
# DER_pt_h                       0.310501     ...         0.623401
# DER_deltaeta_jet_jet          -0.148028     ...        -0.175495
# DER_mass_jet_jet              -0.036482     ...        -0.074390
# DER_prodeta_jet_jet            0.110272     ...         0.123566
# DER_deltar_tau_lep            -0.148081     ...        -0.347904
# DER_pt_tot                     1.000000     ...         0.360409
# DER_sum_pt                     0.381160     ...         0.758503
# DER_pt_ratio_lep_tau           0.039193     ...         0.056312
# DER_met_phi_centrality         0.178448     ...         0.490057
# DER_lep_eta_centrality        -0.121565     ...        -0.130760
# PRI_tau_pt                     0.095754     ...         0.205604
# PRI_tau_eta                    0.003596     ...         0.007468
# PRI_tau_phi                    0.001452     ...         0.003040
# PRI_lep_pt                     0.109617     ...         0.195738
# PRI_lep_eta                    0.007987     ...         0.016054
# PRI_lep_phi                   -0.004249     ...        -0.000040
# PRI_met                        0.269739     ...         0.334922
# PRI_met_phi                    0.002515     ...         0.006575
# PRI_met_sumet                  0.448925     ...         0.705882
# PRI_jet_num                    0.360409     ...         1.000000
# PRI_jet_leading_pt             0.224787     ...         0.360398
# PRI_jet_leading_eta           -0.006168     ...        -0.002185
# PRI_jet_leading_phi            0.004233     ...         0.002314
# PRI_jet_subleading_pt          0.320082     ...         0.281380
# PRI_jet_subleading_eta         0.000730     ...         0.001325
# PRI_jet_subleading_phi        -0.004807     ...        -0.006411
# PRI_jet_all_pt                 0.403382     ...         0.804326
# Weight                        -0.219507     ...        -0.494702
# Label                          0.015287     ...        -0.133549
#
#                              PRI_jet_leading_pt  PRI_jet_leading_eta  \
# EventId                                0.002797             0.002993
# DER_mass_MMC                           0.006454             0.002453
# DER_mass_transverse_met_lep           -0.145892             0.000072
# DER_mass_vis                          -0.076472             0.002569
# DER_pt_h                               0.826278             0.002842
# DER_deltaeta_jet_jet                  -0.043514            -0.002005
# DER_mass_jet_jet                       0.283724            -0.000732
# DER_prodeta_jet_jet                   -0.026637            -0.003548
# DER_deltar_tau_lep                    -0.483625            -0.000157
# DER_pt_tot                             0.224787            -0.006168
# DER_sum_pt                             0.879027             0.000969
# DER_pt_ratio_lep_tau                   0.074943             0.003227
# DER_met_phi_centrality                 0.269991             0.005284
# DER_lep_eta_centrality                 0.003287             0.000581
# PRI_tau_pt                             0.367877             0.000581
# PRI_tau_eta                           -0.003716             0.212850
# PRI_tau_phi                            0.005084             0.002124
# PRI_lep_pt                             0.317445             0.003366
# PRI_lep_eta                           -0.005833             0.235411
# PRI_lep_phi                           -0.004672             0.003932
# PRI_met                                0.615015            -0.001029
# PRI_met_phi                            0.005578             0.002597
# PRI_met_sumet                          0.793776            -0.000012
# PRI_jet_num                            0.360398            -0.002185
# PRI_jet_leading_pt                     1.000000             0.001522
# PRI_jet_leading_eta                    0.001522             1.000000
# PRI_jet_leading_phi                    0.001154            -0.005992
# PRI_jet_subleading_pt                  0.569332             0.001729
# PRI_jet_subleading_eta                -0.000940            -0.231908
# PRI_jet_subleading_phi                -0.004596             0.000878
# PRI_jet_all_pt                         0.878347             0.000158
# Weight                                -0.266753             0.000847
# Label                                 -0.109426            -0.000308
#
#                              PRI_jet_leading_phi  PRI_jet_subleading_pt  \
# EventId                                 0.002165              -0.000039
# DER_mass_MMC                            0.006588              -0.016114
# DER_mass_transverse_met_lep             0.006824              -0.036199
# DER_mass_vis                            0.005583              -0.049472
# DER_pt_h                                0.000993               0.360062
# DER_deltaeta_jet_jet                   -0.000819              -0.090497
# DER_mass_jet_jet                        0.000983               0.235312
# DER_prodeta_jet_jet                    -0.003038               0.002877
# DER_deltar_tau_lep                      0.006808              -0.231997
# DER_pt_tot                              0.004233               0.320082
# DER_sum_pt                              0.003139               0.730235
# DER_pt_ratio_lep_tau                   -0.000534               0.045350
# DER_met_phi_centrality                  0.000005               0.091527
# DER_lep_eta_centrality                 -0.000165              -0.027479
# PRI_tau_pt                              0.004169               0.147108
# PRI_tau_eta                            -0.001120              -0.003750
# PRI_tau_phi                            -0.185520               0.004067
# PRI_lep_pt                              0.001858               0.147492
# PRI_lep_eta                             0.000160              -0.001624
# PRI_lep_phi                            -0.287464              -0.003740
# PRI_met                                 0.003604               0.287686
# PRI_met_phi                            -0.290319               0.003384
# PRI_met_sumet                           0.005147               0.669647
# PRI_jet_num                             0.002314               0.281380
# PRI_jet_leading_pt                      0.001154               0.569332
# PRI_jet_leading_eta                    -0.005992               0.001729
# PRI_jet_leading_phi                     1.000000               0.003308
# PRI_jet_subleading_pt                   0.003308               1.000000
# PRI_jet_subleading_eta                  0.002505               0.000567
# PRI_jet_subleading_phi                 -0.059607              -0.013292
# PRI_jet_all_pt                          0.002224               0.797056
# Weight                                  0.002774              -0.113386
# Label                                   0.000221               0.022613
#
#                              PRI_jet_subleading_eta  PRI_jet_subleading_phi  \
# EventId                                   -0.002718                0.003632
# DER_mass_MMC                               0.004979               -0.001914
# DER_mass_transverse_met_lep                0.001802                0.006880
# DER_mass_vis                               0.002181               -0.000688
# DER_pt_h                                   0.000192               -0.007824
# DER_deltaeta_jet_jet                      -0.004843                0.001234
# DER_mass_jet_jet                          -0.003059               -0.002185
# DER_prodeta_jet_jet                       -0.002528                0.002133
# DER_deltar_tau_lep                         0.001928                0.007244
# DER_pt_tot                                 0.000730               -0.004807
# DER_sum_pt                                -0.000497               -0.008865
# DER_pt_ratio_lep_tau                       0.002864                0.004115
# DER_met_phi_centrality                    -0.003960               -0.013879
# DER_lep_eta_centrality                     0.001430               -0.001266
# PRI_tau_pt                                -0.000712               -0.007061
# PRI_tau_eta                                0.153454                0.001716
# PRI_tau_phi                                0.002319               -0.102875
# PRI_lep_pt                                 0.001343                0.000694
# PRI_lep_eta                                0.163934                0.004023
# PRI_lep_phi                               -0.005820               -0.140200
# PRI_met                                    0.003720               -0.002479
# PRI_met_phi                               -0.008058               -0.128635
# PRI_met_sumet                             -0.000062               -0.007000
# PRI_jet_num                                0.001325               -0.006411
# PRI_jet_leading_pt                        -0.000940               -0.004596
# PRI_jet_leading_eta                       -0.231908                0.000878
# PRI_jet_leading_phi                        0.002505               -0.059607
# PRI_jet_subleading_pt                      0.000567               -0.013292
# PRI_jet_subleading_eta                     1.000000                0.003381
# PRI_jet_subleading_phi                     0.003381                1.000000
# PRI_jet_all_pt                            -0.000763               -0.008902
# Weight                                     0.001381                0.005397
# Label                                     -0.001205                0.006294
#
#                              PRI_jet_all_pt    Weight     Label
# EventId                            0.001024 -0.002838 -0.002248
# DER_mass_MMC                       0.011093  0.098785 -0.011615
# DER_mass_transverse_met_lep       -0.210009  0.419843  0.351428
# DER_mass_vis                      -0.052902  0.102172  0.014055
# DER_pt_h                           0.808616 -0.414084 -0.192526
# DER_deltaeta_jet_jet              -0.108775 -0.277318 -0.328305
# DER_mass_jet_jet                   0.240043 -0.276879 -0.316727
# DER_prodeta_jet_jet                0.018037  0.249448  0.294340
# DER_deltar_tau_lep                -0.448737  0.197881 -0.012245
# DER_pt_tot                         0.403382 -0.219507  0.015287
# DER_sum_pt                         0.965628 -0.414827 -0.153236
# DER_pt_ratio_lep_tau               0.079116  0.188398  0.195398
# DER_met_phi_centrality             0.452224 -0.472163 -0.271752
# DER_lep_eta_centrality            -0.046115 -0.243849 -0.308082
# PRI_tau_pt                         0.321341 -0.284649 -0.235238
# PRI_tau_eta                        0.003763 -0.005647  0.000943
# PRI_tau_phi                        0.004844  0.003224  0.004403
# PRI_lep_pt                         0.295108 -0.020769  0.031948
# PRI_lep_eta                        0.010278 -0.019407 -0.001516
# PRI_lep_phi                       -0.002270 -0.002239 -0.004125
# PRI_met                            0.535217 -0.116031 -0.022466
# PRI_met_phi                        0.007076 -0.009315 -0.007475
# PRI_met_sumet                      0.884413 -0.427235 -0.135520
# PRI_jet_num                        0.804326 -0.494702 -0.133549
# PRI_jet_leading_pt                 0.878347 -0.266753 -0.109426
# PRI_jet_leading_eta                0.000158  0.000847 -0.000308
# PRI_jet_leading_phi                0.002224  0.002774  0.000221
# PRI_jet_subleading_pt              0.797056 -0.113386  0.022613
# PRI_jet_subleading_eta            -0.000763  0.001381 -0.001205
# PRI_jet_subleading_phi            -0.008902  0.005397  0.006294
# PRI_jet_all_pt                     1.000000 -0.419934 -0.134296
# Weight                            -0.419934  1.000000  0.630982
# Label                             -0.134296  0.630982  1.000000
#
# [33 rows x 33 columns]

# %%
df_with_interpolated_values = df.interpolate(method='linear', axis=0)
# Se pueden utilizar diferentes métodos de interpolacion de datos y sobre cualquiera de los dos ejes
df_with_fill_values = df.fillna(df.mean())

# %% [markdown]
# <table width="500px" height="100%"  border="1" style="border: 2px solid red; background-color: ##CC3333 ;">
# <td color="solid green" border= "solid green">
# <img src="images/light.jpg" align='left' alt="description here" />
#  También mirar: <br>
#   - fillna se tienen varias opciones como bfill y ffill.
#   - dropna saca de la tabla todos los valores incompletos. <br>
#   - interpolate cuenta con varios métodos: spline, pchip, polynomial, etc.
#  </td>
# </table>

# %%
df_with_fill_values.info(), df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 250000 entries, 0 to 249999
# Data columns (total 33 columns):
# EventId                        250000 non-null int64
# DER_mass_MMC                   250000 non-null float64
# DER_mass_transverse_met_lep    250000 non-null float64
# DER_mass_vis                   250000 non-null float64
# DER_pt_h                       250000 non-null float64
# DER_deltaeta_jet_jet           250000 non-null float64
# DER_mass_jet_jet               250000 non-null float64
# DER_prodeta_jet_jet            250000 non-null float64
# DER_deltar_tau_lep             250000 non-null float64
# DER_pt_tot                     250000 non-null float64
# DER_sum_pt                     250000 non-null float64
# DER_pt_ratio_lep_tau           250000 non-null float64
# DER_met_phi_centrality         250000 non-null float64
# DER_lep_eta_centrality         250000 non-null float64
# PRI_tau_pt                     250000 non-null float64
# PRI_tau_eta                    250000 non-null float64
# PRI_tau_phi                    250000 non-null float64
# PRI_lep_pt                     250000 non-null float64
# PRI_lep_eta                    250000 non-null float64
# PRI_lep_phi                    250000 non-null float64
# PRI_met                        250000 non-null float64
# PRI_met_phi                    250000 non-null float64
# PRI_met_sumet                  250000 non-null float64
# PRI_jet_num                    250000 non-null int64
# PRI_jet_leading_pt             250000 non-null float64
# PRI_jet_leading_eta            250000 non-null float64
# PRI_jet_leading_phi            250000 non-null float64
# PRI_jet_subleading_pt          250000 non-null float64
# PRI_jet_subleading_eta         250000 non-null float64
# PRI_jet_subleading_phi         250000 non-null float64
# PRI_jet_all_pt                 250000 non-null float64
# Weight                         250000 non-null float64
# Label                          250000 non-null int64
# dtypes: float64(30), int64(3)<class 'pandas.core.frame.DataFrame'>
# Int64Index: 250000 entries, 0 to 249999
# Data columns (total 33 columns):
# EventId                        250000 non-null int64
# DER_mass_MMC                   250000 non-null float64
# DER_mass_transverse_met_lep    250000 non-null float64
# DER_mass_vis                   250000 non-null float64
# DER_pt_h                       250000 non-null float64
# DER_deltaeta_jet_jet           250000 non-null float64
# DER_mass_jet_jet               250000 non-null float64
# DER_prodeta_jet_jet            250000 non-null float64
# DER_deltar_tau_lep             250000 non-null float64
# DER_pt_tot                     250000 non-null float64
# DER_sum_pt                     250000 non-null float64
# DER_pt_ratio_lep_tau           250000 non-null float64
# DER_met_phi_centrality         250000 non-null float64
# DER_lep_eta_centrality         250000 non-null float64
# PRI_tau_pt                     250000 non-null float64
# PRI_tau_eta                    250000 non-null float64
# PRI_tau_phi                    250000 non-null float64
# PRI_lep_pt                     250000 non-null float64
# PRI_lep_eta                    250000 non-null float64
# PRI_lep_phi                    250000 non-null float64
# PRI_met                        250000 non-null float64
# PRI_met_phi                    250000 non-null float64
# PRI_met_sumet                  250000 non-null float64
# PRI_jet_num                    250000 non-null int64
# PRI_jet_leading_pt             250000 non-null float64
# PRI_jet_leading_eta            250000 non-null float64
# PRI_jet_leading_phi            250000 non-null float64
# PRI_jet_subleading_pt          250000 non-null float64
# PRI_jet_subleading_eta         250000 non-null float64
# PRI_jet_subleading_phi         250000 non-null float64
# PRI_jet_all_pt                 250000 non-null float64
# Weight                         250000 non-null float64
# Label                          250000 non-null int64
# dtypes: float64(30), int64(3)
# (None, None)

# %% [markdown]
# #### Ahora queremos separar los datos que usaremos como entrada para crear nuestro clasificador...

# %%
y_fillna = df_with_fill_values['Label'].values
xs_fillna = df_with_fill_values[df.columns[1:-1]].values
# El EventId para ser un cod de cada uno de los eventos, por lo que no cuenta como caracteristica a clasificar
xs_fillinter = df_with_interpolated_values[df.columns[1:-1]].values
y_fillinter = df_with_interpolated_values['Label'].values

# %%
xs = df.dropna()[df.columns[1:-1]].values
y = df.dropna()['Label'].values

# %%
xs = df[df.columns[1:-1]].values
y = df['Label'].values

# %% [markdown]
# ## Paseando por scikit-learn

# %% [markdown]
# #### Primero vamos a querer dividir nuestro dataset, entre los valores que usaremos para entrenar nuestro clasificador y los que usaremos para evaluar que tan bien clasifica ...

# %%
from sklearn.cross_validation import train_test_split
from sklearn.metrics import classification_report, confusion_matrix
from sklearn import metrics
X_train, X_test, y_train, y_test = train_test_split(xs_fillna, y_fillinter, random_state=1)

print """X_train shape : {}, y_train shape : {}
X_test shape : {}, y_test shape : {}""".format(X_train.shape, y_train.shape, X_test.shape, y_test.shape)
# Out:
# X_train shape : (187500, 31), y_train shape : (187500,)
# X_test shape : (62500, 31), y_test shape : (62500,)

# %%
def plot_matrix(clf, X_test, y_test):
    plt.clf()
    plt.imshow(confusion_matrix(clf.predict(X_test), y_test),
               interpolation='nearest', cmap=plt.cm.binary)
    plt.colorbar()
    plt.xlabel("true label")
    plt.ylabel("predicted label")
    plt.show()

# %%
from sklearn.ensemble import ExtraTreesClassifier
import matplotlib.pyplot as plt
clf = ExtraTreesClassifier(n_estimators=10,
                           criterion='gini',
                           max_features=0.2, 
                           n_jobs=2,
                           random_state=1).fit(X_train, y_train)
print classification_report(clf.predict(X_test), y_test)
print clf.score(X_test, y_test)
plot_matrix(clf, X_test, y_test)
# Out:
#              precision    recall  f1-score   support
#
#           0       0.99      0.99      0.99     21370
#           1       0.99      1.00      0.99     41130
#
# avg / total       0.99      0.99      0.99     62500
#
# 0.993392

# %% [markdown]
# #### Cómo saber si nuestro clasificador es realmente bueno ?? deberíamos tener alguna especie de baseline. Pensemos en cómo le iría al peor clasificador del mundo con nuestros datos ...

# %%
from sklearn.dummy import DummyClassifier
clf = DummyClassifier(strategy='most_frequent',random_state=0).fit(X_train, y_train)
#print classification_report(clf.predict(X_test), y_test)
print clf.score(X_test, y_test)
# Out:
# 0.660816

# %%
importances = clf.feature_importances_

# Top 10 features
indices = np.argsort(importances)[::-1]
map(lambda i: (importances[indices[i]], df.columns[1:-1][indices[i]]), range(10))
# Out:
# [(0.64082357877715201, 'Weight'),
#  (0.062290520873918377, 'DER_mass_MMC'),
#  (0.034856577190135685, 'DER_met_phi_centrality'),
#  (0.022588374804636494, 'PRI_tau_pt'),
#  (0.021322802036952148, 'DER_mass_vis'),
#  (0.019321025272920806, 'DER_deltar_tau_lep'),
#  (0.015579521318315855, 'DER_mass_transverse_met_lep'),
#  (0.015134880661774061, 'DER_pt_ratio_lep_tau'),
#  (0.014533954682015843, 'PRI_jet_leading_eta'),
#  (0.013618314093869519, 'DER_lep_eta_centrality')]

# %%
# Out:
# ---------------------------------------------------------------------------
# JoblibValueError                          Traceback (most recent call last)
# <ipython-input-38-53371c548331> in <module>()
# ----> 1 plot_estimator(clf, X_test, y_test)
#
# <ipython-input-37-81fee5baee25> in plot_estimator(estimator, X, y)
#       5     xx, yy = np.meshgrid(np.linspace(x_min, x_max, 50),
#       6                          np.linspace(y_min, y_max, 50))
# ----> 7     Z = estimator.predict(np.c_[xx.ravel(), yy.ravel()])
#       8
#       9     # Put the result into a color plot
#
# /usr/lib/python2.7/site-packages/sklearn/ensemble/forest.pyc in predict(self, X)
#     418         """
#     419         n_samples = len(X)
# --> 420         proba = self.predict_proba(X)
#     421
#     422         if self.n_outputs_ == 1:
#
# /usr/lib/python2.7/site-packages/sklearn/ensemble/forest.pyc in predict_proba(self, X)
#     466                 self.n_classes_,
#     467                 self.n_outputs_)
# --> 468             for i in range(n_jobs))
#     469
#     470         # Reduce
#
# /usr/lib/python2.7/site-packages/sklearn/externals/joblib/parallel.pyc in __call__(self, iterable)
#     649                 # consumption.
#     650                 self._iterating = False
# --> 651             self.retrieve()
#     652             # Make sure that we get a last message telling us we are done
#     653             elapsed_time = time.time() - self._start_time
#
# /usr/lib/python2.7/site-packages/sklearn/externals/joblib/parallel.pyc in retrieve(self)
#     532                         # Convert this to a JoblibException
#     533                         exception_type = _mk_exception(exception.etype)[0]
# --> 534                         raise exception_type(report)
#     535                     raise exception
#     536                 finally:
#
# JoblibValueError: JoblibValueError
# ___________________________________________________________________________
# Multiprocessing exception:
#     ...........................................................................
# /usr/lib/python2.7/runpy.py in _run_module_as_main(mod_name='IPython.kernel.__main__', alter_argv=1)
#     157     pkg_name = mod_name.rpartition('.')[0]
#     158     main_globals = sys.modules["__main__"].__dict__
#     159     if alter_argv:
#     160         sys.argv[0] = fname
#     161     return _run_code(code, main_globals, None,
# --> 162                      "__main__", fname, loader, pkg_name)
#         fname = '/usr/lib/python2.7/site-packages/IPython/kernel/__main__.py'
#         loader = <pkgutil.ImpLoader instance>
#         pkg_name = 'IPython.kernel'
#     163
#     164 def run_module(mod_name, init_globals=None,
#     165                run_name=None, alter_sys=False):
#     166     """Execute a module's code without importing it
#
# ...........................................................................
# /usr/lib/python2.7/runpy.py in _run_code(code=<code object <module> at 0x7fc22b9e8cb0, file "/...ite-packages/IPython/kernel/__main__.py", line 1>, run_globals={'__builtins__': <module '__builtin__' (built-in)>, '__doc__': None, '__file__': '/usr/lib/python2.7/site-packages/IPython/kernel/__main__.py', '__loader__': <pkgutil.ImpLoader instance>, '__name__': '__main__', '__package__': 'IPython.kernel', 'app': <module 'IPython.kernel.zmq.kernelapp' from '/us.../site-packages/IPython/kernel/zmq/kernelapp.pyc'>}, init_globals=None, mod_name='__main__', mod_fname='/usr/lib/python2.7/site-packages/IPython/kernel/__main__.py', mod_loader=<pkgutil.ImpLoader instance>, pkg_name='IPython.kernel')
#      67         run_globals.update(init_globals)
#      68     run_globals.update(__name__ = mod_name,
#      69                        __file__ = mod_fname,
#      70                        __loader__ = mod_loader,
#      71                        __package__ = pkg_name)
# ---> 72     exec code in run_globals
#         code = <code object <module> at 0x7fc22b9e8cb0, file "/...ite-packages/IPython/kernel/__main__.py", line 1>
#         run_globals = {'__builtins__': <module '__builtin__' (built-in)>, '__doc__': None, '__file__': '/usr/lib/python2.7/site-packages/IPython/kernel/__main__.py', '__loader__': <pkgutil.ImpLoader instance>, '__name__': '__main__', '__package__': 'IPython.kernel', 'app': <module 'IPython.kernel.zmq.kernelapp' from '/us.../site-packages/IPython/kernel/zmq/kernelapp.pyc'>}
#      73     return run_globals
#      74
#      75 def _run_module_code(code, init_globals=None,
#      76                     mod_name=None, mod_fname=None,
#
# ...........................................................................
# /usr/lib/python2.7/site-packages/IPython/kernel/__main__.py in <module>()
#       1
#       2
# ----> 3
#       4 if __name__ == '__main__':
#       5     from IPython.kernel.zmq import kernelapp as app
#       6     app.launch_new_instance()
#       7
#       8
#       9
#      10
#
# ...........................................................................
# /usr/lib/python2.7/site-packages/IPython/config/application.py in launch_instance(cls=<class 'IPython.kernel.zmq.kernelapp.IPKernelApp'>, argv=None, **kwargs={})
#     569
#     570         If a global instance already exists, this reinitializes and starts it
#     571         """
#     572         app = cls.instance(**kwargs)
#     573         app.initialize(argv)
# --> 574         app.start()
#         app.start = <bound method IPKernelApp.start of <IPython.kernel.zmq.kernelapp.IPKernelApp object>>
#     575
#     576 #-----------------------------------------------------------------------------
#     577 # utility functions, for convenience
#     578 #-----------------------------------------------------------------------------
#
# ...........................................................................
# /usr/lib/python2.7/site-packages/IPython/kernel/zmq/kernelapp.py in start(self=<IPython.kernel.zmq.kernelapp.IPKernelApp object>)
#     368     def start(self):
#     369         if self.poller is not None:
#     370             self.poller.start()
#     371         self.kernel.start()
#     372         try:
# --> 373             ioloop.IOLoop.instance().start()
#     374         except KeyboardInterrupt:
#     375             pass
#     376
#     377 launch_new_instance = IPKernelApp.launch_instance
#
# ...........................................................................
# /usr/lib/python2.7/site-packages/zmq/eventloop/ioloop.py in start(self=<zmq.eventloop.ioloop.ZMQIOLoop object>)
#     146             PollIOLoop.configure(ZMQIOLoop)
#     147         return PollIOLoop.instance()
#     148
#     149     def start(self):
#     150         try:
# --> 151             super(ZMQIOLoop, self).start()
#         self.start = <bound method ZMQIOLoop.start of <zmq.eventloop.ioloop.ZMQIOLoop object>>
#     152         except ZMQError as e:
#     153             if e.errno == ETERM:
#     154                 # quietly return on ETERM
#     155                 pass
#
# ...........................................................................
# /usr/lib/python2.7/site-packages/tornado/ioloop.py in start(self=<zmq.eventloop.ioloop.ZMQIOLoop object>)
#     832                 self._events.update(event_pairs)
#     833                 while self._events:
#     834                     fd, events = self._events.popitem()
#     835                     try:
#     836                         fd_obj, handler_func = self._handlers[fd]
# --> 837                         handler_func(fd_obj, events)
#         handler_func = <function null_wrapper>
#         fd_obj = <zmq.sugar.socket.Socket object>
#         events = 1
#     838                     except (OSError, IOError) as e:
#     839                         if errno_from_exception(e) == errno.EPIPE:
#     840                             # Happens when the client closes the connection
#     841                             pass
#
# ...........................................................................
# /usr/lib/python2.7/site-packages/tornado/stack_context.py in null_wrapper(*args=(<zmq.sugar.socket.Socket object>, 1), **kwargs={})
#     270         # Fast path when there are no active contexts.
#     271         def null_wrapper(*args, **kwargs):
#     272             try:
#     273                 current_state = _state.contexts
#     274                 _state.contexts = cap_contexts[0]
# --> 275                 return fn(*args, **kwargs)
#         args = (<zmq.sugar.socket.Socket object>, 1)
#         kwargs = {}
#     276             finally:
#     277                 _state.contexts = current_state
#     278         null_wrapper._wrapped = True
#     279         return null_wrapper
#
# ...........................................................................
# /usr/lib/python2.7/site-packages/zmq/eventloop/zmqstream.py in _handle_events(self=<zmq.eventloop.zmqstream.ZMQStream object>, fd=<zmq.sugar.socket.Socket object>, events=1)
#     428             # dispatch events:
#     429             if events & IOLoop.ERROR:
#     430                 gen_log.error("got POLLERR event on ZMQStream, which doesn't make sense")
#     431                 return
#     432             if events & IOLoop.READ:
# --> 433                 self._handle_recv()
#         self._handle_recv = <bound method ZMQStream._handle_recv of <zmq.eventloop.zmqstream.ZMQStream object>>
#     434                 if not self.socket:
#     435                     return
#     436             if events & IOLoop.WRITE:
#     437                 self._handle_send()
#
# ...........................................................................
# /usr/lib/python2.7/site-packages/zmq/eventloop/zmqstream.py in _handle_recv(self=<zmq.eventloop.zmqstream.ZMQStream object>)
#     460                 gen_log.error("RECV Error: %s"%zmq.strerror(e.errno))
#     461         else:
#     462             if self._recv_callback:
#     463                 callback = self._recv_callback
#     464                 # self._recv_callback = None
# --> 465                 self._run_callback(callback, msg)
#         self._run_callback = <bound method ZMQStream._run_callback of <zmq.eventloop.zmqstream.ZMQStream object>>
#         callback = <function null_wrapper>
#         msg = [<zmq.backend.cython.message.Frame object>, <zmq.backend.cython.message.Frame object>, <zmq.backend.cython.message.Frame object>, <zmq.backend.cython.message.Frame object>, <zmq.backend.cython.message.Frame object>, <zmq.backend.cython.message.Frame object>, <zmq.backend.cython.message.Frame object>]
#     466
#     467         # self.update_state()
#     468
#     469
#
# ...........................................................................
# /usr/lib/python2.7/site-packages/zmq/eventloop/zmqstream.py in _run_callback(self=<zmq.eventloop.zmqstream.ZMQStream object>, callback=<function null_wrapper>, *args=([<zmq.backend.cython.message.Frame object>, <zmq.backend.cython.message.Frame object>, <zmq.backend.cython.message.Frame object>, <zmq.backend.cython.message.Frame object>, <zmq.backend.cython.message.Frame object>, <zmq.backend.cython.message.Frame object>, <zmq.backend.cython.message.Frame object>],), **kwargs={})
#     402         close our socket."""
#     403         try:
#     404             # Use a NullContext to ensure that all StackContexts are run
#     405             # inside our blanket exception handler rather than outside.
#     406             with stack_context.NullContext():
# --> 407                 callback(*args, **kwargs)
#         callback = <function null_wrapper>
#         args = ([<zmq.backend.cython.message.Frame object>, <zmq.backend.cython.message.Frame object>, <zmq.backend.cython.message.Frame object>, <zmq.backend.cython.message.Frame object>, <zmq.backend.cython.message.Frame object>, <zmq.backend.cython.message.Frame object>, <zmq.backend.cython.message.Frame object>],)
#         kwargs = {}
#     408         except:
#     409             gen_log.error("Uncaught exception, closing connection.",
#     410                           exc_info=True)
#     411             # Close the socket on an uncaught exception from a user callback
#
# ...........................................................................
# /usr/lib/python2.7/site-packages/tornado/stack_context.py in null_wrapper(*args=([<zmq.backend.cython.message.Frame object>, <zmq.backend.cython.message.Frame object>, <zmq.backend.cython.message.Frame object>, <zmq.backend.cython.message.Frame object>, <zmq.backend.cython.message.Frame object>, <zmq.backend.cython.message.Frame object>, <zmq.backend.cython.message.Frame object>],), **kwargs={})
#     270         # Fast path when there are no active contexts.
#     271         def null_wrapper(*args, **kwargs):
#     272             try:
#     273                 current_state = _state.contexts
#     274                 _state.contexts = cap_contexts[0]
# --> 275                 return fn(*args, **kwargs)
#         args = ([<zmq.backend.cython.message.Frame object>, <zmq.backend.cython.message.Frame object>, <zmq.backend.cython.message.Frame object>, <zmq.backend.cython.message.Frame object>, <zmq.backend.cython.message.Frame object>, <zmq.backend.cython.message.Frame object>, <zmq.backend.cython.message.Frame object>],)
#         kwargs = {}
#     276             finally:
#     277                 _state.contexts = current_state
#     278         null_wrapper._wrapped = True
#     279         return null_wrapper
#
# ...........................................................................
# /usr/lib/python2.7/site-packages/IPython/kernel/zmq/kernelbase.py in dispatcher(msg=[<zmq.backend.cython.message.Frame object>, <zmq.backend.cython.message.Frame object>, <zmq.backend.cython.message.Frame object>, <zmq.backend.cython.message.Frame object>, <zmq.backend.cython.message.Frame object>, <zmq.backend.cython.message.Frame object>, <zmq.backend.cython.message.Frame object>])
#     247         if self.control_stream:
#     248             self.control_stream.on_recv(self.dispatch_control, copy=False)
#     249
#     250         def make_dispatcher(stream):
#     251             def dispatcher(msg):
# --> 252                 return self.dispatch_shell(stream, msg)
#         msg = [<zmq.backend.cython.message.Frame object>, <zmq.backend.cython.message.Frame object>, <zmq.backend.cython.message.Frame object>, <zmq.backend.cython.message.Frame object>, <zmq.backend.cython.message.Frame object>, <zmq.backend.cython.message.Frame object>, <zmq.backend.cython.message.Frame object>]
#     253             return dispatcher
#     254
#     255         for s in self.shell_streams:
#     256             s.on_recv(make_dispatcher(s), copy=False)
#
# ...........................................................................
# /usr/lib/python2.7/site-packages/IPython/kernel/zmq/kernelbase.py in dispatch_shell(self=<IPython.kernel.zmq.ipkernel.IPythonKernel object>, stream=<zmq.eventloop.zmqstream.ZMQStream object>, msg={'buffers': [], 'content': {'allow_stdin': True, 'code': 'plot_estimator(clf, X_test, y_test)', 'silent': False, 'stop_on_error': True, 'store_history': True, 'user_expressions': {}}, 'header': {'msg_id': '391BDC0C8AE2449D9CDC74EB1C97E1F8', 'msg_type': 'execute_request', 'session': 'E9387B4B8B9346D485B3646055A50083', 'username': 'username', 'version': '5.0'}, 'metadata': {}, 'msg_id': '391BDC0C8AE2449D9CDC74EB1C97E1F8', 'msg_type': 'execute_request', 'parent_header': {}})
#     208         else:
#     209             # ensure default_int_handler during handler call
#     210             sig = signal(SIGINT, default_int_handler)
#     211             self.log.debug("%s: %s", msg_type, msg)
#     212             try:
# --> 213                 handler(stream, idents, msg)
#         handler = <bound method IPythonKernel.execute_request of <IPython.kernel.zmq.ipkernel.IPythonKernel object>>
#         stream = <zmq.eventloop.zmqstream.ZMQStream object>
#         idents = ['E9387B4B8B9346D485B3646055A50083']
#         msg = {'buffers': [], 'content': {'allow_stdin': True, 'code': 'plot_estimator(clf, X_test, y_test)', 'silent': False, 'stop_on_error': True, 'store_history': True, 'user_expressions': {}}, 'header': {'msg_id': '391BDC0C8AE2449D9CDC74EB1C97E1F8', 'msg_type': 'execute_request', 'session': 'E9387B4B8B9346D485B3646055A50083', 'username': 'username', 'version': '5.0'}, 'metadata': {}, 'msg_id': '391BDC0C8AE2449D9CDC74EB1C97E1F8', 'msg_type': 'execute_request', 'parent_header': {}}
#     214             except Exception:
#     215                 self.log.error("Exception in message handler:", exc_info=True)
#     216             finally:
#     217                 signal(SIGINT, sig)
#
# ...........................................................................
# /usr/lib/python2.7/site-packages/IPython/kernel/zmq/kernelbase.py in execute_request(self=<IPython.kernel.zmq.ipkernel.IPythonKernel object>, stream=<zmq.eventloop.zmqstream.ZMQStream object>, ident=['E9387B4B8B9346D485B3646055A50083'], parent={'buffers': [], 'content': {'allow_stdin': True, 'code': 'plot_estimator(clf, X_test, y_test)', 'silent': False, 'stop_on_error': True, 'store_history': True, 'user_expressions': {}}, 'header': {'msg_id': '391BDC0C8AE2449D9CDC74EB1C97E1F8', 'msg_type': 'execute_request', 'session': 'E9387B4B8B9346D485B3646055A50083', 'username': 'username', 'version': '5.0'}, 'metadata': {}, 'msg_id': '391BDC0C8AE2449D9CDC74EB1C97E1F8', 'msg_type': 'execute_request', 'parent_header': {}})
#     357         if not silent:
#     358             self.execution_count += 1
#     359             self._publish_execute_input(code, parent, self.execution_count)
#     360
#     361         reply_content = self.do_execute(code, silent, store_history,
# --> 362                                         user_expressions, allow_stdin)
#         user_expressions = {}
#         allow_stdin = True
#     363
#     364         # Flush output before sending the reply.
#     365         sys.stdout.flush()
#     366         sys.stderr.flush()
#
# ...........................................................................
# /usr/lib/python2.7/site-packages/IPython/kernel/zmq/ipkernel.py in do_execute(self=<IPython.kernel.zmq.ipkernel.IPythonKernel object>, code=u'plot_estimator(clf, X_test, y_test)', silent=False, store_history=True, user_expressions={}, allow_stdin=True)
#     176
#     177         reply_content = {}
#     178         # FIXME: the shell calls the exception handler itself.
#     179         shell._reply_content = None
#     180         try:
# --> 181             shell.run_cell(code, store_history=store_history, silent=silent)
#         shell.run_cell = <bound method ZMQInteractiveShell.run_cell of <I....kernel.zmq.zmqshell.ZMQInteractiveShell object>>
#         code = u'plot_estimator(clf, X_test, y_test)'
#         store_history = True
#         silent = False
#     182         except:
#     183             status = u'error'
#     184             # FIXME: this code right now isn't being used yet by default,
#     185             # because the run_cell() call above directly fires off exception
#
# ...........................................................................
# /usr/lib/python2.7/site-packages/IPython/core/interactiveshell.py in run_cell(self=<IPython.kernel.zmq.zmqshell.ZMQInteractiveShell object>, raw_cell=u'plot_estimator(clf, X_test, y_test)', store_history=True, silent=False, shell_futures=True)
#    2866                 self.displayhook.exec_result = result
#    2867
#    2868                 # Execute the user code
#    2869                 interactivity = "none" if silent else self.ast_node_interactivity
#    2870                 self.run_ast_nodes(code_ast.body, cell_name,
# -> 2871                    interactivity=interactivity, compiler=compiler, result=result)
#         interactivity = 'last_expr'
#         compiler = <IPython.core.compilerop.CachingCompiler instance>
#    2872
#    2873                 # Reset this so later displayed values do not modify the
#    2874                 # ExecutionResult
#    2875                 self.displayhook.exec_result = None
#
# ...........................................................................
# /usr/lib/python2.7/site-packages/IPython/core/interactiveshell.py in run_ast_nodes(self=<IPython.kernel.zmq.zmqshell.ZMQInteractiveShell object>, nodelist=[<_ast.Expr object>], cell_name='<ipython-input-38-53371c548331>', interactivity='last', compiler=<IPython.core.compilerop.CachingCompiler instance>, result=<IPython.core.interactiveshell.ExecutionResult object>)
#    2976                     return True
#    2977
#    2978             for i, node in enumerate(to_run_interactive):
#    2979                 mod = ast.Interactive([node])
#    2980                 code = compiler(mod, cell_name, "single")
# -> 2981                 if self.run_code(code, result):
#         self.run_code = <bound method ZMQInteractiveShell.run_code of <I....kernel.zmq.zmqshell.ZMQInteractiveShell object>>
#         code = <code object <module> at 0x27d3730, file "<ipython-input-38-53371c548331>", line 1>
#         result = <IPython.core.interactiveshell.ExecutionResult object>
#    2982                     return True
#    2983
#    2984             # Flush softspace
#    2985             if softspace(sys.stdout, 0):
#
# ...........................................................................
# /usr/lib/python2.7/site-packages/IPython/core/interactiveshell.py in run_code(self=<IPython.kernel.zmq.zmqshell.ZMQInteractiveShell object>, code_obj=<code object <module> at 0x27d3730, file "<ipython-input-38-53371c548331>", line 1>, result=<IPython.core.interactiveshell.ExecutionResult object>)
#    3030         outflag = 1  # happens in more places, so it's easier as default
#    3031         try:
#    3032             try:
#    3033                 self.hooks.pre_run_code_hook()
#    3034                 #rprint('Running code', repr(code_obj)) # dbg
# -> 3035                 exec(code_obj, self.user_global_ns, self.user_ns)
#         code_obj = <code object <module> at 0x27d3730, file "<ipython-input-38-53371c548331>", line 1>
#         self.user_global_ns = {'DummyClassifier': <class 'sklearn.dummy.DummyClassifier'>, 'ExtraTreesClassifier': <class 'sklearn.ensemble.forest.ExtraTreesClassifier'>, 'IFrame': <class 'IPython.lib.display.IFrame'>, 'In': ['', u"from IPython.display import IFrame\nIFrame('http://pandas.pydata.org/', width=900, height=350)", u'import pandas as pd\nimport numpy as np', u'import pandas as pd\nimport numpy as np', u'import pandas as pd\nimport numpy as np', u"from IPython.display import IFrame\nIFrame('http://pandas.pydata.org/', width=900, height=350)", u'import pandas as pd\nimport numpy as np', u"df = pd.read_csv('data/training.csv') #, na_va...] = df['Label'].map({'s': 0, 'b':1}).astype(int)", u"xs = df[df.columns[1:-1]].values\ny = df['Label'].values", u"xs = df[df.columns[1:-1]].values\ny = df['Label'].values", u'from sklearn.cross_validation import train_tes...hape, y_train.shape, X_test.shape, y_test.shape)', u'from sklearn.cross_validation import train_tes...hape, y_train.shape, X_test.shape, y_test.shape)', u"from sklearn.ensemble import ExtraTreesClassif...t)\nprint clf.score(clf.predict(X_test), y_test)", u"from sklearn.ensemble import ExtraTreesClassif...)\n#print clf.score(clf.predict(X_test), y_test)", u"from sklearn.ensemble import ExtraTreesClassif...t)\nprint clf.score(clf.predict(X_test), y_test)", u"from sklearn.dummy import DummyClassifier\nclf...t)\nprint clf.score(clf.predict(X_test), y_test)", u"from sklearn.ensemble import ExtraTreesClassif...t)\nprint clf.score(clf.predict(X_test), y_test)", u"from sklearn.ensemble import ExtraTreesClassif...\nprint clf.score(clf.predict(X_train), y_train)", u"from sklearn.ensemble import ExtraTreesClassif...n#print clf.score(clf.predict(X_train), y_train)", u"from sklearn.ensemble import ExtraTreesClassif...n#print clf.score(clf.predict(X_train), y_train)", ...], 'Out': {1: <IPython.lib.display.IFrame object>, 5: <IPython.lib.display.IFrame object>}, 'X_test': array([[  1.00368000e+02,   3.58310000e+01,   7....000000e+02,  -0.00000000e+00,   1.45484847e+00]]), 'X_train': array([[-999.        ,   78.176     ,  112.743  ...        ,
#           -0.        ,    1.68161144]]), '_': <IPython.lib.display.IFrame object>, '_1': <IPython.lib.display.IFrame object>, '_5': <IPython.lib.display.IFrame object>, ...}
#         self.user_ns = {'DummyClassifier': <class 'sklearn.dummy.DummyClassifier'>, 'ExtraTreesClassifier': <class 'sklearn.ensemble.forest.ExtraTreesClassifier'>, 'IFrame': <class 'IPython.lib.display.IFrame'>, 'In': ['', u"from IPython.display import IFrame\nIFrame('http://pandas.pydata.org/', width=900, height=350)", u'import pandas as pd\nimport numpy as np', u'import pandas as pd\nimport numpy as np', u'import pandas as pd\nimport numpy as np', u"from IPython.display import IFrame\nIFrame('http://pandas.pydata.org/', width=900, height=350)", u'import pandas as pd\nimport numpy as np', u"df = pd.read_csv('data/training.csv') #, na_va...] = df['Label'].map({'s': 0, 'b':1}).astype(int)", u"xs = df[df.columns[1:-1]].values\ny = df['Label'].values", u"xs = df[df.columns[1:-1]].values\ny = df['Label'].values", u'from sklearn.cross_validation import train_tes...hape, y_train.shape, X_test.shape, y_test.shape)', u'from sklearn.cross_validation import train_tes...hape, y_train.shape, X_test.shape, y_test.shape)', u"from sklearn.ensemble import ExtraTreesClassif...t)\nprint clf.score(clf.predict(X_test), y_test)", u"from sklearn.ensemble import ExtraTreesClassif...)\n#print clf.score(clf.predict(X_test), y_test)", u"from sklearn.ensemble import ExtraTreesClassif...t)\nprint clf.score(clf.predict(X_test), y_test)", u"from sklearn.dummy import DummyClassifier\nclf...t)\nprint clf.score(clf.predict(X_test), y_test)", u"from sklearn.ensemble import ExtraTreesClassif...t)\nprint clf.score(clf.predict(X_test), y_test)", u"from sklearn.ensemble import ExtraTreesClassif...\nprint clf.score(clf.predict(X_train), y_train)", u"from sklearn.ensemble import ExtraTreesClassif...n#print clf.score(clf.predict(X_train), y_train)", u"from sklearn.ensemble import ExtraTreesClassif...n#print clf.score(clf.predict(X_train), y_train)", ...], 'Out': {1: <IPython.lib.display.IFrame object>, 5: <IPython.lib.display.IFrame object>}, 'X_test': array([[  1.00368000e+02,   3.58310000e+01,   7....000000e+02,  -0.00000000e+00,   1.45484847e+00]]), 'X_train': array([[-999.        ,   78.176     ,  112.743  ...        ,
#           -0.        ,    1.68161144]]), '_': <IPython.lib.display.IFrame object>, '_1': <IPython.lib.display.IFrame object>, '_5': <IPython.lib.display.IFrame object>, ...}
#    3036             finally:
#    3037                 # Reset our crash handler in place
#    3038                 sys.excepthook = old_excepthook
#    3039         except SystemExit as e:
#
# ...........................................................................
# /home/celia/Documents/Conferencias/2015/scipyla/pre-scipyla/<ipython-input-38-53371c548331> in <module>()
# ----> 1
#       2
#       3
#       4
#       5
#       6 plot_estimator(clf, X_test, y_test)
#       7
#       8
#       9
#      10
#
# ...........................................................................
# /home/celia/Documents/Conferencias/2015/scipyla/pre-scipyla/<ipython-input-37-81fee5baee25> in plot_estimator(estimator=ExtraTreesClassifier(bootstrap=False, compute_im...core=False,
#            random_state=1, verbose=0), X=array([[  1.00368000e+02,   3.58310000e+01,   7....000000e+02,  -0.00000000e+00,   1.45484847e+00]]), y=array([0, 1, 1, ..., 0, 1, 1]))
#       2     estimator.fit(X, y)
#       3     x_min, x_max = X[:, 0].min() - .1, X[:, 0].max() + .1
#       4     y_min, y_max = X[:, 1].min() - .1, X[:, 1].max() + .1
#       5     xx, yy = np.meshgrid(np.linspace(x_min, x_max, 50),
#       6                          np.linspace(y_min, y_max, 50))
# ----> 7     Z = estimator.predict(np.c_[xx.ravel(), yy.ravel()])
#       8
#       9     # Put the result into a color plot
#      10     Z = Z.reshape(xx.shape)
#      11     plt.figure()
#
# ...........................................................................
# /usr/lib/python2.7/site-packages/sklearn/ensemble/forest.py in predict(self=ExtraTreesClassifier(bootstrap=False, compute_im...core=False,
#            random_state=1, verbose=0), X=array([[ -9.99100000e+02,  -1.00000000e-01],
#    ...2],
#        [  9.85202000e+02,   5.71968000e+02]]))
#     415         -------
#     416         y : array of shape = [n_samples] or [n_samples, n_outputs]
#     417             The predicted classes.
#     418         """
#     419         n_samples = len(X)
# --> 420         proba = self.predict_proba(X)
#         proba = undefined
#         self.predict_proba = <bound method ExtraTreesClassifier.predict_proba...ore=False,
#            random_state=1, verbose=0)>
#         X = array([[ -9.99100000e+02,  -1.00000000e-01],
#    ...2],
#        [  9.85202000e+02,   5.71968000e+02]])
#     421
#     422         if self.n_outputs_ == 1:
#     423             return self.classes_.take(np.argmax(proba, axis=1), axis=0)
#     424
#
# ...........................................................................
# /usr/lib/python2.7/site-packages/sklearn/ensemble/forest.py in predict_proba(self=ExtraTreesClassifier(bootstrap=False, compute_im...core=False,
#            random_state=1, verbose=0), X=array([[ -9.99099976e+02,  -1.00000001e-01],
#    ....85202026e+02,   5.71968018e+02]], dtype=float32))
#     463             delayed(_parallel_predict_proba)(
#     464                 self.estimators_[starts[i]:starts[i + 1]],
#     465                 X,
#     466                 self.n_classes_,
#     467                 self.n_outputs_)
# --> 468             for i in range(n_jobs))
#         n_jobs = 2
#     469
#     470         # Reduce
#     471         proba = all_proba[0]
#     472
#
# ...........................................................................
# /usr/lib/python2.7/site-packages/sklearn/externals/joblib/parallel.py in __call__(self=Parallel(n_jobs=2), iterable=<generator object <genexpr>>)
#     646             if pre_dispatch == "all" or n_jobs == 1:
#     647                 # The iterable was consumed all at once by the above for loop.
#     648                 # No need to wait for async callbacks to trigger to
#     649                 # consumption.
#     650                 self._iterating = False
# --> 651             self.retrieve()
#         self.retrieve = <bound method Parallel.retrieve of Parallel(n_jobs=2)>
#     652             # Make sure that we get a last message telling us we are done
#     653             elapsed_time = time.time() - self._start_time
#     654             self._print('Done %3i out of %3i | elapsed: %s finished',
#     655                         (len(self._output),
#
#     ---------------------------------------------------------------------------
#     Sub-process traceback:
#     ---------------------------------------------------------------------------
#     ValueError                                         Thu May  7 16:29:08 2015
# PID: 27324                                   Python 2.7.4: /usr/bin/python2
# ...........................................................................
# /usr/lib/python2.7/site-packages/sklearn/ensemble/forest.pyc in _parallel_predict_proba(trees=[ExtraTreeClassifier(compute_importances=None, cr...      random_state=1791095845, splitter='random'), ExtraTreeClassifier(compute_importances=None, cr...      random_state=2135392491, splitter='random'), ExtraTreeClassifier(compute_importances=None, cr...       random_state=946286476, splitter='random'), ExtraTreeClassifier(compute_importances=None, cr...      random_state=1857819720, splitter='random'), ExtraTreeClassifier(compute_importances=None, cr...          random_state=491263, splitter='random')], X=array([[ -9.99099976e+02,  -1.00000001e-01],
#    ....85202026e+02,   5.71968018e+02]], dtype=float32), n_classes=2, n_outputs=1)
#     104
#     105     if n_outputs == 1:
#     106         proba = np.zeros((n_samples, n_classes))
#     107
#     108         for tree in trees:
# --> 109             proba_tree = tree.predict_proba(X)
#     110
#     111             if n_classes == tree.n_classes_:
#     112                 proba += proba_tree
#     113
#
# ...........................................................................
# /usr/lib/python2.7/site-packages/sklearn/tree/tree.pyc in predict_proba(self=ExtraTreeClassifier(compute_importances=None, cr...      random_state=1791095845, splitter='random'), X=array([[ -9.99099976e+02,  -1.00000001e-01],
#    ....85202026e+02,   5.71968018e+02]], dtype=float32))
#     515
#     516         if self.n_features_ != n_features:
#     517             raise ValueError("Number of features of the model must "
#     518                              " match the input. Model n_features is %s and "
#     519                              " input n_features is %s "
# --> 520                              % (self.n_features_, n_features))
#     521
#     522         proba = self.tree_.predict(X)
#     523
#     524         if self.n_outputs_ == 1:
#
# ValueError: Number of features of the model must  match the input. Model n_features is 31 and  input n_features is 2
# ___________________________________________________________________________
